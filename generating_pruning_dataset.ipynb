# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils.prune as prune
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import pandas as pd
import numpy as np

torch.manual_seed(42)
np.random.seed(42)

# %%
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)
print("MNIST dataset loaded with train and test loaders.")
# Out:
# MNIST dataset loaded with train and test loaders.

# %%
class SimpleNet(nn.Module):
    def __init__(self, hidden_size):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(784, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 10)  
    def forward(self, x):
        x = x.view(-1, 784)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def train_model(model, train_loader, epochs=3, device=device):
    criterion = nn.CrossEntropyLoss().to(device) 
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    model.train()
    for epoch in range(epochs):
        for data, target in train_loader:
            data, target = data.to(device), target.to(device) 
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch+1}/{epochs} completed on {device}.")
    return model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 def train_model(model, train_loader, epochs=3, device=cuda):
#       2     criterion = nn.CrossEntropyLoss().to(device)
#       3     optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
#
# NameError: name 'cuda' is not defined

# %%
# Evaluation function (GPU-optimized)
def evaluate_model(model, test_loader, device=device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  # Move data to GPU
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    accuracy = correct / total
    print(f"Evaluated accuracy: {accuracy:.4f} on {device}")
    return accuracy
print("Evaluation function updated for GPU.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Evaluation function (GPU-optimized)
# ----> 2 def evaluate_model(model, test_loader, device=device):
#       3     model.eval()
#       4     correct = 0
#
# NameError: name 'device' is not defined

# %%
# Define expanded parameters for at least 200 rows (GPU-optimized)
hidden_sizes = [16, 32, 64, 128, 256, 512, 1024, 2048]  # 8 values
prune_ratios = [0.2, 0.4, 0.6, 0.8, 0.9]  # 5 values
dataset_complexities = [0.1, 0.3, 0.5, 0.7, 1.0]  # 5 values (MNIST data fractions)
expected_rows = len(hidden_sizes) * len(prune_ratios) * len(dataset_complexities)
print(f"Expected rows: {expected_rows} (approx. 200)")
# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Expected rows: 200 (approx. 200)
# Using device: cuda

# %%
import os
import pandas as pd

# Initialize data list and counter
data = []
counter = 0

# Generate pruning data with GPU optimization
for hidden_size in hidden_sizes:
    for prune_ratio in prune_ratios:
        for complexity in dataset_complexities:
            # Adjust train_loader size based on complexity
            train_subset = torch.utils.data.Subset(train_dataset, range(int(len(train_dataset) * complexity)))
            train_loader_subset = torch.utils.data.DataLoader(train_subset, batch_size=128, shuffle=True)  # GPU-friendly batch
            print(f"Training model #{counter+1}/{expected_rows}: hidden_size={hidden_size}, prune_ratio={prune_ratio}, complexity={complexity}")
            
            # Train a model on GPU
            model = SimpleNet(hidden_size).to(device)
            model = train_model(model, train_loader_subset, epochs=3, device=device)
            baseline_accuracy = evaluate_model(model, test_loader, device=device)  # Ensure test on GPU
            
            # Prune the first layer (on GPU)
            prune.l1_unstructured(model.fc1, name="weight", amount=prune_ratio)
            pruned_accuracy = evaluate_model(model, test_loader, device=device)
            
            # Store data
            accuracy_drop = max(0, baseline_accuracy - pruned_accuracy)  # Clamp non-negative
            data.append({
                'hidden_size': hidden_size,
                'prune_ratio': prune_ratio,
                'dataset_complexity': complexity,
                'accuracy_drop': accuracy_drop
            })
            counter += 1
            
            # Partial save every 50 rows (to resume if interrupted)
            if counter % 50 == 0 or counter == expected_rows:
                partial_df = pd.DataFrame(data)
                partial_df.to_csv('partial_pruning_data.csv', index=False)
                print(f"Partial save at {counter} rows: 'partial_pruning_data.csv'")

# Save full dataset
df = pd.DataFrame(data)
df.to_csv('pruning_data.csv', index=False)
print(f"Dataset generated and saved to 'pruning_data.csv' with {len(df)} rows:")
print(df.head())
print(df.describe())  # Check stats for accuracy_drop range
# Out:
# Training model #1/200: hidden_size=16, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8502 on cuda
# Evaluated accuracy: 0.8501 on cuda
# Training model #2/200: hidden_size=16, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8998 on cuda
# Evaluated accuracy: 0.9002 on cuda
# Training model #3/200: hidden_size=16, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9119 on cuda
# Evaluated accuracy: 0.9120 on cuda
# Training model #4/200: hidden_size=16, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9180 on cuda
# Evaluated accuracy: 0.9172 on cuda
# Training model #5/200: hidden_size=16, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9314 on cuda
# Evaluated accuracy: 0.9310 on cuda
# Training model #6/200: hidden_size=16, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8527 on cuda
# Evaluated accuracy: 0.8537 on cuda
# Training model #7/200: hidden_size=16, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9037 on cuda
# Evaluated accuracy: 0.9034 on cuda
# Training model #8/200: hidden_size=16, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9132 on cuda
# Evaluated accuracy: 0.9114 on cuda
# Training model #9/200: hidden_size=16, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9166 on cuda
# Evaluated accuracy: 0.9153 on cuda
# Training model #10/200: hidden_size=16, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9258 on cuda
# Evaluated accuracy: 0.9249 on cuda
# Training model #11/200: hidden_size=16, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8546 on cuda
# Evaluated accuracy: 0.8493 on cuda
# Training model #12/200: hidden_size=16, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9042 on cuda
# Evaluated accuracy: 0.9033 on cuda
# Training model #13/200: hidden_size=16, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9119 on cuda
# Evaluated accuracy: 0.9094 on cuda
# Training model #14/200: hidden_size=16, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9205 on cuda
# Evaluated accuracy: 0.9163 on cuda
# Training model #15/200: hidden_size=16, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9251 on cuda
# Evaluated accuracy: 0.9256 on cuda
# Training model #16/200: hidden_size=16, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8613 on cuda
# Evaluated accuracy: 0.8566 on cuda
# Training model #17/200: hidden_size=16, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9039 on cuda
# Evaluated accuracy: 0.8929 on cuda
# Training model #18/200: hidden_size=16, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9154 on cuda
# Evaluated accuracy: 0.9033 on cuda
# Training model #19/200: hidden_size=16, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9233 on cuda
# Evaluated accuracy: 0.9026 on cuda
# Training model #20/200: hidden_size=16, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9261 on cuda
# Evaluated accuracy: 0.9109 on cuda
# Training model #21/200: hidden_size=16, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8523 on cuda
# Evaluated accuracy: 0.8181 on cuda
# Training model #22/200: hidden_size=16, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9017 on cuda
# Evaluated accuracy: 0.8541 on cuda
# Training model #23/200: hidden_size=16, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9137 on cuda
# Evaluated accuracy: 0.8810 on cuda
# Training model #24/200: hidden_size=16, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9176 on cuda
# Evaluated accuracy: 0.8695 on cuda
# Training model #25/200: hidden_size=16, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9276 on cuda
# Evaluated accuracy: 0.8794 on cuda
# Training model #26/200: hidden_size=32, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8684 on cuda
# Evaluated accuracy: 0.8683 on cuda
# Training model #27/200: hidden_size=32, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9051 on cuda
# Evaluated accuracy: 0.9047 on cuda
# Training model #28/200: hidden_size=32, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9183 on cuda
# Evaluated accuracy: 0.9180 on cuda
# Training model #29/200: hidden_size=32, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9264 on cuda
# Evaluated accuracy: 0.9268 on cuda
# Training model #30/200: hidden_size=32, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9291 on cuda
# Evaluated accuracy: 0.9289 on cuda
# Training model #31/200: hidden_size=32, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8637 on cuda
# Evaluated accuracy: 0.8650 on cuda
# Training model #32/200: hidden_size=32, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9042 on cuda
# Evaluated accuracy: 0.9046 on cuda
# Training model #33/200: hidden_size=32, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9176 on cuda
# Evaluated accuracy: 0.9177 on cuda
# Training model #34/200: hidden_size=32, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9254 on cuda
# Evaluated accuracy: 0.9262 on cuda
# Training model #35/200: hidden_size=32, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9313 on cuda
# Evaluated accuracy: 0.9322 on cuda
# Training model #36/200: hidden_size=32, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8630 on cuda
# Evaluated accuracy: 0.8616 on cuda
# Training model #37/200: hidden_size=32, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9048 on cuda
# Evaluated accuracy: 0.9011 on cuda
# Training model #38/200: hidden_size=32, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9205 on cuda
# Evaluated accuracy: 0.9170 on cuda
# Training model #39/200: hidden_size=32, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9234 on cuda
# Evaluated accuracy: 0.9225 on cuda
# Training model #40/200: hidden_size=32, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9325 on cuda
# Evaluated accuracy: 0.9309 on cuda
# Training model #41/200: hidden_size=32, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8622 on cuda
# Evaluated accuracy: 0.8544 on cuda
# Training model #42/200: hidden_size=32, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9023 on cuda
# Evaluated accuracy: 0.8958 on cuda
# Training model #43/200: hidden_size=32, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9172 on cuda
# Evaluated accuracy: 0.9121 on cuda
# Training model #44/200: hidden_size=32, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9254 on cuda
# Evaluated accuracy: 0.9126 on cuda
# Training model #45/200: hidden_size=32, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9334 on cuda
# Evaluated accuracy: 0.9258 on cuda
# Training model #46/200: hidden_size=32, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8657 on cuda
# Evaluated accuracy: 0.8410 on cuda
# Training model #47/200: hidden_size=32, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9056 on cuda
# Evaluated accuracy: 0.8754 on cuda
# Training model #48/200: hidden_size=32, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9168 on cuda
# Evaluated accuracy: 0.8809 on cuda
# Training model #49/200: hidden_size=32, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9240 on cuda
# Evaluated accuracy: 0.8548 on cuda
# Training model #50/200: hidden_size=32, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9296 on cuda
# Evaluated accuracy: 0.8789 on cuda
# Partial save at 50 rows: 'partial_pruning_data.csv'
# Training model #51/200: hidden_size=64, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8609 on cuda
# Evaluated accuracy: 0.8595 on cuda
# Training model #52/200: hidden_size=64, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9071 on cuda
# Evaluated accuracy: 0.9076 on cuda
# Training model #53/200: hidden_size=64, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9212 on cuda
# Evaluated accuracy: 0.9210 on cuda
# Training model #54/200: hidden_size=64, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9291 on cuda
# Evaluated accuracy: 0.9291 on cuda
# Training model #55/200: hidden_size=64, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9337 on cuda
# Evaluated accuracy: 0.9336 on cuda
# Training model #56/200: hidden_size=64, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8678 on cuda
# Evaluated accuracy: 0.8683 on cuda
# Training model #57/200: hidden_size=64, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9065 on cuda
# Evaluated accuracy: 0.9059 on cuda
# Training model #58/200: hidden_size=64, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9203 on cuda
# Evaluated accuracy: 0.9188 on cuda
# Training model #59/200: hidden_size=64, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9269 on cuda
# Evaluated accuracy: 0.9262 on cuda
# Training model #60/200: hidden_size=64, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9355 on cuda
# Evaluated accuracy: 0.9350 on cuda
# Training model #61/200: hidden_size=64, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8725 on cuda
# Evaluated accuracy: 0.8697 on cuda
# Training model #62/200: hidden_size=64, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9068 on cuda
# Evaluated accuracy: 0.9038 on cuda
# Training model #63/200: hidden_size=64, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9186 on cuda
# Evaluated accuracy: 0.9167 on cuda
# Training model #64/200: hidden_size=64, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9241 on cuda
# Evaluated accuracy: 0.9237 on cuda
# Training model #65/200: hidden_size=64, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9372 on cuda
# Evaluated accuracy: 0.9356 on cuda
# Training model #66/200: hidden_size=64, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8659 on cuda
# Evaluated accuracy: 0.8607 on cuda
# Training model #67/200: hidden_size=64, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9075 on cuda
# Evaluated accuracy: 0.9021 on cuda
# Training model #68/200: hidden_size=64, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9184 on cuda
# Evaluated accuracy: 0.9157 on cuda
# Training model #69/200: hidden_size=64, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9272 on cuda
# Evaluated accuracy: 0.9192 on cuda
# Training model #70/200: hidden_size=64, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9345 on cuda
# Evaluated accuracy: 0.9316 on cuda
# Training model #71/200: hidden_size=64, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8685 on cuda
# Evaluated accuracy: 0.8563 on cuda
# Training model #72/200: hidden_size=64, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9079 on cuda
# Evaluated accuracy: 0.8814 on cuda
# Training model #73/200: hidden_size=64, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9188 on cuda
# Evaluated accuracy: 0.8929 on cuda
# Training model #74/200: hidden_size=64, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9292 on cuda
# Evaluated accuracy: 0.9129 on cuda
# Training model #75/200: hidden_size=64, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9354 on cuda
# Evaluated accuracy: 0.9103 on cuda
# Training model #76/200: hidden_size=128, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8729 on cuda
# Evaluated accuracy: 0.8725 on cuda
# Training model #77/200: hidden_size=128, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9093 on cuda
# Evaluated accuracy: 0.9091 on cuda
# Training model #78/200: hidden_size=128, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9199 on cuda
# Evaluated accuracy: 0.9200 on cuda
# Training model #79/200: hidden_size=128, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9301 on cuda
# Evaluated accuracy: 0.9303 on cuda
# Training model #80/200: hidden_size=128, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9411 on cuda
# Evaluated accuracy: 0.9406 on cuda
# Training model #81/200: hidden_size=128, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8700 on cuda
# Evaluated accuracy: 0.8700 on cuda
# Training model #82/200: hidden_size=128, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9096 on cuda
# Evaluated accuracy: 0.9097 on cuda
# Training model #83/200: hidden_size=128, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9211 on cuda
# Evaluated accuracy: 0.9200 on cuda
# Training model #84/200: hidden_size=128, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9305 on cuda
# Evaluated accuracy: 0.9310 on cuda
# Training model #85/200: hidden_size=128, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9360 on cuda
# Evaluated accuracy: 0.9354 on cuda
# Training model #86/200: hidden_size=128, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8628 on cuda
# Evaluated accuracy: 0.8620 on cuda
# Training model #87/200: hidden_size=128, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9071 on cuda
# Evaluated accuracy: 0.9049 on cuda
# Training model #88/200: hidden_size=128, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9210 on cuda
# Evaluated accuracy: 0.9203 on cuda
# Training model #89/200: hidden_size=128, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9283 on cuda
# Evaluated accuracy: 0.9277 on cuda
# Training model #90/200: hidden_size=128, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9382 on cuda
# Evaluated accuracy: 0.9363 on cuda
# Training model #91/200: hidden_size=128, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8728 on cuda
# Evaluated accuracy: 0.8716 on cuda
# Training model #92/200: hidden_size=128, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9081 on cuda
# Evaluated accuracy: 0.9034 on cuda
# Training model #93/200: hidden_size=128, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9214 on cuda
# Evaluated accuracy: 0.9175 on cuda
# Training model #94/200: hidden_size=128, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9301 on cuda
# Evaluated accuracy: 0.9278 on cuda
# Training model #95/200: hidden_size=128, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9375 on cuda
# Evaluated accuracy: 0.9326 on cuda
# Training model #96/200: hidden_size=128, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8701 on cuda
# Evaluated accuracy: 0.8651 on cuda
# Training model #97/200: hidden_size=128, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9085 on cuda
# Evaluated accuracy: 0.8946 on cuda
# Training model #98/200: hidden_size=128, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9199 on cuda
# Evaluated accuracy: 0.9113 on cuda
# Training model #99/200: hidden_size=128, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9296 on cuda
# Evaluated accuracy: 0.9161 on cuda
# Training model #100/200: hidden_size=128, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9398 on cuda
# Evaluated accuracy: 0.9226 on cuda
# Partial save at 100 rows: 'partial_pruning_data.csv'
# Training model #101/200: hidden_size=256, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8751 on cuda
# Evaluated accuracy: 0.8748 on cuda
# Training model #102/200: hidden_size=256, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9087 on cuda
# Evaluated accuracy: 0.9086 on cuda
# Training model #103/200: hidden_size=256, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9237 on cuda
# Evaluated accuracy: 0.9237 on cuda
# Training model #104/200: hidden_size=256, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9331 on cuda
# Evaluated accuracy: 0.9328 on cuda
# Training model #105/200: hidden_size=256, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9388 on cuda
# Evaluated accuracy: 0.9394 on cuda
# Training model #106/200: hidden_size=256, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8704 on cuda
# Evaluated accuracy: 0.8697 on cuda
# Training model #107/200: hidden_size=256, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9084 on cuda
# Evaluated accuracy: 0.9072 on cuda
# Training model #108/200: hidden_size=256, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9227 on cuda
# Evaluated accuracy: 0.9225 on cuda
# Training model #109/200: hidden_size=256, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9313 on cuda
# Evaluated accuracy: 0.9321 on cuda
# Training model #110/200: hidden_size=256, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9419 on cuda
# Evaluated accuracy: 0.9410 on cuda
# Training model #111/200: hidden_size=256, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8758 on cuda
# Evaluated accuracy: 0.8747 on cuda
# Training model #112/200: hidden_size=256, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9092 on cuda
# Evaluated accuracy: 0.9084 on cuda
# Training model #113/200: hidden_size=256, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9232 on cuda
# Evaluated accuracy: 0.9221 on cuda
# Training model #114/200: hidden_size=256, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9323 on cuda
# Evaluated accuracy: 0.9318 on cuda
# Training model #115/200: hidden_size=256, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9410 on cuda
# Evaluated accuracy: 0.9397 on cuda
# Training model #116/200: hidden_size=256, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8672 on cuda
# Evaluated accuracy: 0.8580 on cuda
# Training model #117/200: hidden_size=256, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9095 on cuda
# Evaluated accuracy: 0.9083 on cuda
# Training model #118/200: hidden_size=256, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9225 on cuda
# Evaluated accuracy: 0.9180 on cuda
# Training model #119/200: hidden_size=256, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9275 on cuda
# Evaluated accuracy: 0.9220 on cuda
# Training model #120/200: hidden_size=256, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9411 on cuda
# Evaluated accuracy: 0.9381 on cuda
# Training model #121/200: hidden_size=256, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8667 on cuda
# Evaluated accuracy: 0.8540 on cuda
# Training model #122/200: hidden_size=256, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9088 on cuda
# Evaluated accuracy: 0.9007 on cuda
# Training model #123/200: hidden_size=256, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9224 on cuda
# Evaluated accuracy: 0.9109 on cuda
# Training model #124/200: hidden_size=256, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9300 on cuda
# Evaluated accuracy: 0.9232 on cuda
# Training model #125/200: hidden_size=256, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9394 on cuda
# Evaluated accuracy: 0.9317 on cuda
# Training model #126/200: hidden_size=512, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8748 on cuda
# Evaluated accuracy: 0.8746 on cuda
# Training model #127/200: hidden_size=512, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9118 on cuda
# Evaluated accuracy: 0.9125 on cuda
# Training model #128/200: hidden_size=512, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9225 on cuda
# Evaluated accuracy: 0.9216 on cuda
# Training model #129/200: hidden_size=512, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9322 on cuda
# Evaluated accuracy: 0.9324 on cuda
# Training model #130/200: hidden_size=512, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9435 on cuda
# Evaluated accuracy: 0.9430 on cuda
# Training model #131/200: hidden_size=512, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8690 on cuda
# Evaluated accuracy: 0.8686 on cuda
# Training model #132/200: hidden_size=512, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9077 on cuda
# Evaluated accuracy: 0.9077 on cuda
# Training model #133/200: hidden_size=512, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9245 on cuda
# Evaluated accuracy: 0.9241 on cuda
# Training model #134/200: hidden_size=512, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9326 on cuda
# Evaluated accuracy: 0.9319 on cuda
# Training model #135/200: hidden_size=512, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9404 on cuda
# Evaluated accuracy: 0.9407 on cuda
# Training model #136/200: hidden_size=512, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8759 on cuda
# Evaluated accuracy: 0.8737 on cuda
# Training model #137/200: hidden_size=512, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9104 on cuda
# Evaluated accuracy: 0.9112 on cuda
# Training model #138/200: hidden_size=512, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9243 on cuda
# Evaluated accuracy: 0.9219 on cuda
# Training model #139/200: hidden_size=512, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9329 on cuda
# Evaluated accuracy: 0.9322 on cuda
# Training model #140/200: hidden_size=512, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9411 on cuda
# Evaluated accuracy: 0.9413 on cuda
# Training model #141/200: hidden_size=512, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8733 on cuda
# Evaluated accuracy: 0.8642 on cuda
# Training model #142/200: hidden_size=512, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9095 on cuda
# Evaluated accuracy: 0.9050 on cuda
# Training model #143/200: hidden_size=512, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9246 on cuda
# Evaluated accuracy: 0.9231 on cuda
# Training model #144/200: hidden_size=512, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9338 on cuda
# Evaluated accuracy: 0.9284 on cuda
# Training model #145/200: hidden_size=512, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9435 on cuda
# Evaluated accuracy: 0.9411 on cuda
# Training model #146/200: hidden_size=512, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8738 on cuda
# Evaluated accuracy: 0.8752 on cuda
# Training model #147/200: hidden_size=512, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9107 on cuda
# Evaluated accuracy: 0.9018 on cuda
# Training model #148/200: hidden_size=512, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9248 on cuda
# Evaluated accuracy: 0.9164 on cuda
# Training model #149/200: hidden_size=512, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9332 on cuda
# Evaluated accuracy: 0.9239 on cuda
# Training model #150/200: hidden_size=512, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9419 on cuda
# Evaluated accuracy: 0.9356 on cuda
# Partial save at 150 rows: 'partial_pruning_data.csv'
# Training model #151/200: hidden_size=1024, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8831 on cuda
# Evaluated accuracy: 0.8833 on cuda
# Training model #152/200: hidden_size=1024, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9141 on cuda
# Evaluated accuracy: 0.9145 on cuda
# Training model #153/200: hidden_size=1024, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9264 on cuda
# Evaluated accuracy: 0.9258 on cuda
# Training model #154/200: hidden_size=1024, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9344 on cuda
# Evaluated accuracy: 0.9342 on cuda
# Training model #155/200: hidden_size=1024, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9401 on cuda
# Evaluated accuracy: 0.9399 on cuda
# Training model #156/200: hidden_size=1024, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8749 on cuda
# Evaluated accuracy: 0.8745 on cuda
# Training model #157/200: hidden_size=1024, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9135 on cuda
# Evaluated accuracy: 0.9145 on cuda
# Training model #158/200: hidden_size=1024, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9235 on cuda
# Evaluated accuracy: 0.9216 on cuda
# Training model #159/200: hidden_size=1024, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9352 on cuda
# Evaluated accuracy: 0.9349 on cuda
# Training model #160/200: hidden_size=1024, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9440 on cuda
# Evaluated accuracy: 0.9429 on cuda
# Training model #161/200: hidden_size=1024, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8782 on cuda
# Evaluated accuracy: 0.8778 on cuda
# Training model #162/200: hidden_size=1024, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9132 on cuda
# Evaluated accuracy: 0.9129 on cuda
# Training model #163/200: hidden_size=1024, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9258 on cuda
# Evaluated accuracy: 0.9248 on cuda
# Training model #164/200: hidden_size=1024, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9358 on cuda
# Evaluated accuracy: 0.9344 on cuda
# Training model #165/200: hidden_size=1024, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9417 on cuda
# Evaluated accuracy: 0.9399 on cuda
# Training model #166/200: hidden_size=1024, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8745 on cuda
# Evaluated accuracy: 0.8711 on cuda
# Training model #167/200: hidden_size=1024, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9135 on cuda
# Evaluated accuracy: 0.9089 on cuda
# Training model #168/200: hidden_size=1024, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9266 on cuda
# Evaluated accuracy: 0.9223 on cuda
# Training model #169/200: hidden_size=1024, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9348 on cuda
# Evaluated accuracy: 0.9265 on cuda
# Training model #170/200: hidden_size=1024, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9427 on cuda
# Evaluated accuracy: 0.9389 on cuda
# Training model #171/200: hidden_size=1024, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8763 on cuda
# Evaluated accuracy: 0.8726 on cuda
# Training model #172/200: hidden_size=1024, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9137 on cuda
# Evaluated accuracy: 0.9089 on cuda
# Training model #173/200: hidden_size=1024, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9271 on cuda
# Evaluated accuracy: 0.9187 on cuda
# Training model #174/200: hidden_size=1024, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9345 on cuda
# Evaluated accuracy: 0.9258 on cuda
# Training model #175/200: hidden_size=1024, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9396 on cuda
# Evaluated accuracy: 0.9319 on cuda
# Training model #176/200: hidden_size=2048, prune_ratio=0.2, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8812 on cuda
# Evaluated accuracy: 0.8814 on cuda
# Training model #177/200: hidden_size=2048, prune_ratio=0.2, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9168 on cuda
# Evaluated accuracy: 0.9166 on cuda
# Training model #178/200: hidden_size=2048, prune_ratio=0.2, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9285 on cuda
# Evaluated accuracy: 0.9282 on cuda
# Training model #179/200: hidden_size=2048, prune_ratio=0.2, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9356 on cuda
# Evaluated accuracy: 0.9361 on cuda
# Training model #180/200: hidden_size=2048, prune_ratio=0.2, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9461 on cuda
# Evaluated accuracy: 0.9465 on cuda
# Training model #181/200: hidden_size=2048, prune_ratio=0.4, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8822 on cuda
# Evaluated accuracy: 0.8815 on cuda
# Training model #182/200: hidden_size=2048, prune_ratio=0.4, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9164 on cuda
# Evaluated accuracy: 0.9159 on cuda
# Training model #183/200: hidden_size=2048, prune_ratio=0.4, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9270 on cuda
# Evaluated accuracy: 0.9264 on cuda
# Training model #184/200: hidden_size=2048, prune_ratio=0.4, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9341 on cuda
# Evaluated accuracy: 0.9347 on cuda
# Training model #185/200: hidden_size=2048, prune_ratio=0.4, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9462 on cuda
# Evaluated accuracy: 0.9448 on cuda
# Training model #186/200: hidden_size=2048, prune_ratio=0.6, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8809 on cuda
# Evaluated accuracy: 0.8804 on cuda
# Training model #187/200: hidden_size=2048, prune_ratio=0.6, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9143 on cuda
# Evaluated accuracy: 0.9117 on cuda
# Training model #188/200: hidden_size=2048, prune_ratio=0.6, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9292 on cuda
# Evaluated accuracy: 0.9278 on cuda
# Training model #189/200: hidden_size=2048, prune_ratio=0.6, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9332 on cuda
# Evaluated accuracy: 0.9340 on cuda
# Training model #190/200: hidden_size=2048, prune_ratio=0.6, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9464 on cuda
# Evaluated accuracy: 0.9460 on cuda
# Training model #191/200: hidden_size=2048, prune_ratio=0.8, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8856 on cuda
# Evaluated accuracy: 0.8784 on cuda
# Training model #192/200: hidden_size=2048, prune_ratio=0.8, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9145 on cuda
# Evaluated accuracy: 0.9110 on cuda
# Training model #193/200: hidden_size=2048, prune_ratio=0.8, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9270 on cuda
# Evaluated accuracy: 0.9196 on cuda
# Training model #194/200: hidden_size=2048, prune_ratio=0.8, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9370 on cuda
# Evaluated accuracy: 0.9334 on cuda
# Training model #195/200: hidden_size=2048, prune_ratio=0.8, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9456 on cuda
# Evaluated accuracy: 0.9411 on cuda
# Training model #196/200: hidden_size=2048, prune_ratio=0.9, complexity=0.1
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.8853 on cuda
# Evaluated accuracy: 0.8662 on cuda
# Training model #197/200: hidden_size=2048, prune_ratio=0.9, complexity=0.3
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9150 on cuda
# Evaluated accuracy: 0.9032 on cuda
# Training model #198/200: hidden_size=2048, prune_ratio=0.9, complexity=0.5
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9282 on cuda
# Evaluated accuracy: 0.9034 on cuda
# Training model #199/200: hidden_size=2048, prune_ratio=0.9, complexity=0.7
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9378 on cuda
# Evaluated accuracy: 0.9227 on cuda
# Training model #200/200: hidden_size=2048, prune_ratio=0.9, complexity=1.0
# Epoch 1/3 completed on cuda.
# Epoch 2/3 completed on cuda.
# Epoch 3/3 completed on cuda.
# Evaluated accuracy: 0.9437 on cuda
# Evaluated accuracy: 0.9348 on cuda
# Partial save at 200 rows: 'partial_pruning_data.csv'
# Dataset generated and saved to 'pruning_data.csv' with 200 rows:
#    hidden_size  prune_ratio  dataset_complexity  accuracy_drop
# 0           16          0.2                 0.1         0.0001
# 1           16          0.2                 0.3         0.0000
# 2           16          0.2                 0.5         0.0000
# 3           16          0.2                 0.7         0.0008
# 4           16          0.2                 1.0         0.0004
#        hidden_size  prune_ratio  dataset_complexity  accuracy_drop
# count   200.000000   200.000000          200.000000     200.000000
# mean    510.000000     0.580000            0.520000       0.005547
# std     664.188022     0.256768            0.313194       0.010275
# min      16.000000     0.200000            0.100000       0.000000
# 25%      56.000000     0.400000            0.300000       0.000300
# 50%     192.000000     0.600000            0.500000       0.001400
# 75%     640.000000     0.800000            0.700000       0.005700
# max    2048.000000     0.900000            1.000000       0.069200
